# %% [markdown]
# # Importing Libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import RandomOverSampler 
import numpy as np
from sklearn.model_selection import train_test_split
import os, cv2
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D

# %% [markdown]
# # Import Data

# %%
import pandas as pd
data = pd.read_csv('/kaggle/input/skin-cancer-mnist-ham10000/hmnist_28_28_RGB.csv')
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
y = data['label']
x = data.drop(columns = ['label'])

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
tabular_data = pd.read_csv('/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_metadata.csv')
tabular_data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
classes = {4: ('nv', ' melanocytic nevi'), 6: ('mel', 'melanoma'), 2 :('bkl', 'benign keratosis-like lesions'), 1:('bcc' , ' basal cell carcinoma'), 5: ('vasc', ' pyogenic granulomas and hemorrhage'), 0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),  3: ('df', 'dermatofibroma')}

# %% [markdown]
# # Oversampling
# **To overcome class imbalace**

# %%
oversample = RandomOverSampler()
x,y  = oversample.fit_resample(x,y)

# %%
x = np.array(x).reshape(-1,28,28,3)
print('Shape of X :',x.shape)
# Out:
# Shape of X : (46935, 28, 28, 3)

# %% [markdown]
# # Standardization and Splitting Data

# %%
x = (x-np.mean(x))/np.std(x)
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2, random_state=1)

# %% [markdown]
# # Model Training

# %%
model = Sequential()
# 16 filter
model.add(Conv2D(16, kernel_size = (3,3), input_shape = (28, 28, 3), activation = 'relu', padding = 'same'))
# 32 filter
model.add(Conv2D(32, kernel_size = (3,3), activation = 'relu'))
model.add(MaxPool2D(pool_size = (2,2)))
# pooling will divide by 2 the shape
model.add(Conv2D(32, kernel_size = (3,3), activation = 'relu', padding = 'same'))
# 64 filter
model.add(Conv2D(64, kernel_size = (3,3), activation = 'relu'))
model.add(MaxPool2D(pool_size = (2,2), padding = 'same'))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(7, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 16)        448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        4640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 13, 13, 32)        9248
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                147520
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 182,663
# Trainable params: 182,663
# Non-trainable params: 0
# _________________________________________________________________

# %%
callback = tf.keras.callbacks.ModelCheckpoint(filepath='best_model.h5',
                                                  monitor='val_acc', mode='max',
                                                 verbose=1)

# %%
model.compile(loss = 'sparse_categorical_crossentropy',
             optimizer = 'adam',
              metrics = ['accuracy'])
history = model.fit(X_train,
                    Y_train,
                    validation_split=0.2,
                    batch_size = 128,
                    epochs = 20,
                    callbacks=[callback])
# Out:
# Epoch 1/20
# 235/235 [==============================] - 32s 135ms/step - loss: 1.4981 - accuracy: 0.4147 - val_loss: 0.8980 - val_accuracy: 0.6687
#
# Epoch 00001: saving model to best_model.h5
# Epoch 2/20
# 235/235 [==============================] - 30s 128ms/step - loss: 0.7924 - accuracy: 0.7134 - val_loss: 0.5987 - val_accuracy: 0.7888
#
# Epoch 00002: saving model to best_model.h5
# Epoch 3/20
# 235/235 [==============================] - 30s 128ms/step - loss: 0.5078 - accuracy: 0.8144 - val_loss: 0.4289 - val_accuracy: 0.8437
#
# Epoch 00003: saving model to best_model.h5
# Epoch 4/20
# 235/235 [==============================] - 30s 128ms/step - loss: 0.3578 - accuracy: 0.8724 - val_loss: 0.3176 - val_accuracy: 0.8846
#
# Epoch 00004: saving model to best_model.h5
# Epoch 5/20
# 235/235 [==============================] - 30s 127ms/step - loss: 0.2583 - accuracy: 0.9055 - val_loss: 0.2404 - val_accuracy: 0.9115
#
# Epoch 00005: saving model to best_model.h5
# Epoch 6/20
# 235/235 [==============================] - 30s 127ms/step - loss: 0.2029 - accuracy: 0.9270 - val_loss: 0.2344 - val_accuracy: 0.9180
#
# Epoch 00006: saving model to best_model.h5
# Epoch 7/20
# 235/235 [==============================] - 30s 128ms/step - loss: 0.1830 - accuracy: 0.9313 - val_loss: 0.1905 - val_accuracy: 0.9406
#
# Epoch 00007: saving model to best_model.h5
# Epoch 8/20
# 235/235 [==============================] - 30s 127ms/step - loss: 0.1318 - accuracy: 0.9537 - val_loss: 0.2007 - val_accuracy: 0.9360
#
# Epoch 00008: saving model to best_model.h5
# Epoch 9/20
# 235/235 [==============================] - 30s 127ms/step - loss: 0.1147 - accuracy: 0.9603 - val_loss: 0.2553 - val_accuracy: 0.9136
#
# Epoch 00009: saving model to best_model.h5
# Epoch 10/20
# 235/235 [==============================] - 30s 127ms/step - loss: 0.1259 - accuracy: 0.9553 - val_loss: 0.1584 - val_accuracy: 0.9525
#
# Epoch 00010: saving model to best_model.h5
# Epoch 11/20
# 235/235 [==============================] - 30s 127ms/step - loss: 0.0767 - accuracy: 0.9731 - val_loss: 0.2028 - val_accuracy: 0.9386
#
# Epoch 00011: saving model to best_model.h5
# Epoch 12/20
# 235/235 [==============================] - 30s 127ms/step - loss: 0.0777 - accuracy: 0.9735 - val_loss: 0.1796 - val_accuracy: 0.9403
#
# Epoch 00012: saving model to best_model.h5
# Epoch 13/20
# 235/235 [==============================] - 30s 127ms/step - loss: 0.0666 - accuracy: 0.9765 - val_loss: 0.1578 - val_accuracy: 0.9606
#
# Epoch 00013: saving model to best_model.h5
# Epoch 14/20
# 235/235 [==============================] - 30s 126ms/step - loss: 0.0527 - accuracy: 0.9816 - val_loss: 0.2640 - val_accuracy: 0.9174
#
# Epoch 00014: saving model to best_model.h5
# Epoch 15/20
# 235/235 [==============================] - 30s 127ms/step - loss: 0.0813 - accuracy: 0.9740 - val_loss: 0.1423 - val_accuracy: 0.9634
#
# Epoch 00015: saving model to best_model.h5
# Epoch 16/20
# 235/235 [==============================] - 30s 127ms/step - loss: 0.0299 - accuracy: 0.9900 - val_loss: 0.1809 - val_accuracy: 0.9498
#
# Epoch 00016: saving model to best_model.h5
# Epoch 17/20
# 235/235 [==============================] - 30s 126ms/step - loss: 0.0582 - accuracy: 0.9792 - val_loss: 0.1396 - val_accuracy: 0.9675
#
# Epoch 00017: saving model to best_model.h5
# Epoch 18/20
# 235/235 [==============================] - 30s 126ms/step - loss: 0.0323 - accuracy: 0.9887 - val_loss: 0.1797 - val_accuracy: 0.9586
#
# Epoch 00018: saving model to best_model.h5
# Epoch 19/20
# 235/235 [==============================] - 29s 125ms/step - loss: 0.0545 - accuracy: 0.9815 - val_loss: 0.2053 - val_accuracy: 0.9474
#
# Epoch 00019: saving model to best_model.h5
# Epoch 20/20
# 235/235 [==============================] - 30s 127ms/step - loss: 0.0713 - accuracy: 0.9766 - val_loss: 0.1615 - val_accuracy: 0.9700
#
# Epoch 00020: saving model to best_model.h5

# %% [markdown]
# # Plot Accuracy and Loss

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model.load_weights('best_model.h5')

# %% [markdown]
# # Model Testing

# %%
loss, acc = model.evaluate(X_test, Y_test, verbose=2)
# Out:
# 294/294 - 3s - loss: 0.1469 - accuracy: 0.9706

# %%
pred = model.predict(X_test[0].reshape(-1,28,28,3))
key = pred.argmax(axis=1)
classes[key[0]]
# Out:
# ('vasc', ' pyogenic granulomas and hemorrhage')

# %% [markdown]
# # Model Inference

# %%
# !pip install google.colab
from google.colab.patches import cv2_imshow
srcdir = '/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_1'
count=0
for temp in os.listdir(srcdir):
    img = cv2.imread(os.path.join(srcdir, temp))
    cv2.imwrite(temp, img)
    cv2_imshow(img)
    img = cv2.resize(img, (28, 28))
    result = model.predict(img.reshape(1, 28, 28, 3))
    max_prob = max(result[0])
    class_ind = list(result[0]).index(max_prob)
    class_name = classes[class_ind]
    print(class_name)
    count+=1
    if count>10:
        break
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fc1f4f4f1d0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/google-colab/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fc1f4f4f590>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/google-colab/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fc1f4f4f8d0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/google-colab/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fc1f4f4fc10>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/google-colab/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fc1f4f4ff50>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/google-colab/
# ERROR: Could not find a version that satisfies the requirement google.colab
# ERROR: No matching distribution found for google.colab
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-b54336a54ff4> in <module>
#       1 get_ipython().system('pip install google.colab')
# ----> 2 from google.colab.patches import cv2_imshow
#       3 srcdir = '/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_1'
#       4 count=0
#       5 for temp in os.listdir(srcdir):
#
# ModuleNotFoundError: No module named 'google.colab'
